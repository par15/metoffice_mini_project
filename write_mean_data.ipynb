# %%
## code that writes ensemble means at a specific time for each day over a period of a year to a netcdf file

import numpy as np
import netCDF4 as nc
import mogreps

# %%
def calculate_mean(lat,lon,year,month,day,hour,ensemble_size):
    
    from pathlib import Path
    
    temp_mean = 0.
    pres_mean = 0.
    humidity_mean = 0.
    wind_mean = 0.
    
    for i in range(ensemble_size):
        
        print(i)
        try:
            file_name = mogreps.download_data(
            'mogreps-uk',mogreps.make_data_object_name('mogreps-uk',year,month,day,hour,i,3),data_folder = Path('.'))
        except:
            print(file_name)
        dataset = nc.Dataset(file_name,'r')
        
        
        # read temperature
        
        temp = dataset.variables['air_temperature'][0,0,lat,lon]
        
        # read pressure
        
        pressure = dataset.variables['surface_air_pressure'][0,lat,lon]
        
        # read humidity
        
        humidity = dataset.variables['relative_humidity'][0,0,lat,lon]
        
        # read wind_speed
        
        u_wind = dataset.variables['x_wind'][0,0,lat,lon]
        
        v_wind = dataset.variables['y_wind'][0,0,lat,lon]
        
        wind_speed = np.sqrt(u_wind**2 + v_wind**2)
        
        # close file
        
        dataset.close()
        
        # calculate means
        
        temp_mean = temp_mean + temp
        pres_mean = pres_mean + pressure
        humidity_mean = humidity_mean + humidity
        wind_mean = wind_mean + wind_speed
        

    # normalise mean
    
    temp_mean = temp_mean/ensemble_size
    pres_mean = pres_mean/ensemble_size
    humidity_mean = humidity_mean/ensemble_size
    wind_mean = wind_mean/ensemble_size
    
    return temp_mean, pres_mean, humidity_mean, wind_mean

# %%
ensemble_size = 8
n_months = 12
n_days = 31

temp_mean = []
pres_mean = []
humidity_mean = []
wind_mean = []

# %%
for m in range(n_months):
    for d in range(n_days):
        temp,pres,humidity,wind = calculate_mean(0,0,2014,m+1,d+1,3,ensemble_size)
        
        temp_mean.append(temp)
        pres_mean.append(pres)
        humidity_mean.append(humidity)
        wind_mean.append(wind)
# Out:
# 0
# File prods_op_mogreps-uk_20140101_03_00_003.nc already exists.
# 1
# File prods_op_mogreps-uk_20140101_03_01_003.nc already exists.
# 2
# File prods_op_mogreps-uk_20140101_03_02_003.nc already exists.
# 3
# File prods_op_mogreps-uk_20140101_03_03_003.nc already exists.
# 4
# File prods_op_mogreps-uk_20140101_03_04_003.nc already exists.
# 5
# File prods_op_mogreps-uk_20140101_03_05_003.nc already exists.
# 6
# File prods_op_mogreps-uk_20140101_03_06_003.nc already exists.
# 7
# File prods_op_mogreps-uk_20140101_03_07_003.nc already exists.
# 0
# Downloading prods_op_mogreps-uk_20140102_03_00_003.nc ...
# 1
# Downloading prods_op_mogreps-uk_20140102_03_01_003.nc ...
# 2
# Downloading prods_op_mogreps-uk_20140102_03_02_003.nc ...
# 3
# Downloading prods_op_mogreps-uk_20140102_03_03_003.nc ...
# 4
# Downloading prods_op_mogreps-uk_20140102_03_04_003.nc ...
# 5
# Downloading prods_op_mogreps-uk_20140102_03_05_003.nc ...
# 6
# Downloading prods_op_mogreps-uk_20140102_03_06_003.nc ...
# 7
# Downloading prods_op_mogreps-uk_20140102_03_07_003.nc ...
# 0
# Downloading prods_op_mogreps-uk_20140103_03_00_003.nc ...
# 1
# Downloading prods_op_mogreps-uk_20140103_03_01_003.nc ...
# 2
# Downloading prods_op_mogreps-uk_20140103_03_02_003.nc ...
# 3
# Downloading prods_op_mogreps-uk_20140103_03_03_003.nc ...
# 4
# Downloading prods_op_mogreps-uk_20140103_03_04_003.nc ...
# 5
# Downloading prods_op_mogreps-uk_20140103_03_05_003.nc ...
# 6
# Downloading prods_op_mogreps-uk_20140103_03_06_003.nc ...
# 7
# Downloading prods_op_mogreps-uk_20140103_03_07_003.nc ...
# 0
# Downloading prods_op_mogreps-uk_20140104_03_00_003.nc ...
# 1
# Downloading prods_op_mogreps-uk_20140104_03_01_003.nc ...
# 2
# Downloading prods_op_mogreps-uk_20140104_03_02_003.nc ...
# 3
# Downloading prods_op_mogreps-uk_20140104_03_03_003.nc ...
# 4
# Downloading prods_op_mogreps-uk_20140104_03_04_003.nc ...
# 5
# Downloading prods_op_mogreps-uk_20140104_03_05_003.nc ...
# 6
# Downloading prods_op_mogreps-uk_20140104_03_06_003.nc ...
# 7
# Downloading prods_op_mogreps-uk_20140104_03_07_003.nc ...
# 0
# Downloading prods_op_mogreps-uk_20140105_03_00_003.nc ...
# 1
# Downloading prods_op_mogreps-uk_20140105_03_01_003.nc ...
# 2
# Downloading prods_op_mogreps-uk_20140105_03_02_003.nc ...
# 3
# Downloading prods_op_mogreps-uk_20140105_03_03_003.nc ...
# 4
# Downloading prods_op_mogreps-uk_20140105_03_04_003.nc ...
# 5
# Downloading prods_op_mogreps-uk_20140105_03_05_003.nc ...
# 6
# Downloading prods_op_mogreps-uk_20140105_03_06_003.nc ...
# 7
# Downloading prods_op_mogreps-uk_20140105_03_07_003.nc ...
# 0
# Downloading prods_op_mogreps-uk_20140106_03_00_003.nc ...
# 1
# Downloading prods_op_mogreps-uk_20140106_03_01_003.nc ...
# 2
# Downloading prods_op_mogreps-uk_20140106_03_02_003.nc ...
# 3
# Downloading prods_op_mogreps-uk_20140106_03_03_003.nc ...
# 4
# Downloading prods_op_mogreps-uk_20140106_03_04_003.nc ...
# 5
# Downloading prods_op_mogreps-uk_20140106_03_05_003.nc ...
# 6
# Downloading prods_op_mogreps-uk_20140106_03_06_003.nc ...
# 7
# Downloading prods_op_mogreps-uk_20140106_03_07_003.nc ...
# 0
# Downloading prods_op_mogreps-uk_20140107_03_00_003.nc ...
# 1
# Downloading prods_op_mogreps-uk_20140107_03_01_003.nc ...
# 2
# Downloading prods_op_mogreps-uk_20140107_03_02_003.nc ...
# 3
# Downloading prods_op_mogreps-uk_20140107_03_03_003.nc ...
# 4
# Downloading prods_op_mogreps-uk_20140107_03_04_003.nc ...
# 5
# Downloading prods_op_mogreps-uk_20140107_03_05_003.nc ...
# 6
# Downloading prods_op_mogreps-uk_20140107_03_06_003.nc ...
# 7
# Downloading prods_op_mogreps-uk_20140107_03_07_003.nc ...
# 0
# Downloading prods_op_mogreps-uk_20140108_03_00_003.nc ...
# 1
# Downloading prods_op_mogreps-uk_20140108_03_01_003.nc ...
# 2
# Downloading prods_op_mogreps-uk_20140108_03_02_003.nc ...
# 3
# Downloading prods_op_mogreps-uk_20140108_03_03_003.nc ...
# 4
# Downloading prods_op_mogreps-uk_20140108_03_04_003.nc ...
# 5
# Downloading prods_op_mogreps-uk_20140108_03_05_003.nc ...
# 6
# Downloading prods_op_mogreps-uk_20140108_03_06_003.nc ...
# 7
# Downloading prods_op_mogreps-uk_20140108_03_07_003.nc ...
# 0
# Downloading prods_op_mogreps-uk_20140109_03_00_003.nc ...
# 1
# Downloading prods_op_mogreps-uk_20140109_03_01_003.nc ...
# 2
# Downloading prods_op_mogreps-uk_20140109_03_02_003.nc ...
# 3
# Downloading prods_op_mogreps-uk_20140109_03_03_003.nc ...
# 4
# Downloading prods_op_mogreps-uk_20140109_03_04_003.nc ...
# 5
# Downloading prods_op_mogreps-uk_20140109_03_05_003.nc ...
# 6
# Downloading prods_op_mogreps-uk_20140109_03_06_003.nc ...
# 7
# Downloading prods_op_mogreps-uk_20140109_03_07_003.nc ...
# 0
# Downloading prods_op_mogreps-uk_20140110_03_00_003.nc ...
# 1
# Downloading prods_op_mogreps-uk_20140110_03_01_003.nc ...
# 2
# Downloading prods_op_mogreps-uk_20140110_03_02_003.nc ...
# 3
# Downloading prods_op_mogreps-uk_20140110_03_03_003.nc ...
# 4
# Downloading prods_op_mogreps-uk_20140110_03_04_003.nc ...
# 5
# Downloading prods_op_mogreps-uk_20140110_03_05_003.nc ...
# 6
# Downloading prods_op_mogreps-uk_20140110_03_06_003.nc ...
# 7
# Downloading prods_op_mogreps-uk_20140110_03_07_003.nc ...
# 0
# Downloading prods_op_mogreps-uk_20140111_03_00_003.nc ...
# 1
# Downloading prods_op_mogreps-uk_20140111_03_01_003.nc ...
# 2
# Downloading prods_op_mogreps-uk_20140111_03_02_003.nc ...
# 3
# Downloading prods_op_mogreps-uk_20140111_03_03_003.nc ...
# 4
# Downloading prods_op_mogreps-uk_20140111_03_04_003.nc ...
# 5
# Downloading prods_op_mogreps-uk_20140111_03_05_003.nc ...
# 6
# Downloading prods_op_mogreps-uk_20140111_03_06_003.nc ...
# 7
# Downloading prods_op_mogreps-uk_20140111_03_07_003.nc ...
# 0
# Downloading prods_op_mogreps-uk_20140112_03_00_003.nc ...
# 1
# Downloading prods_op_mogreps-uk_20140112_03_01_003.nc ...
# 2
# Downloading prods_op_mogreps-uk_20140112_03_02_003.nc ...
# 3
# Downloading prods_op_mogreps-uk_20140112_03_03_003.nc ...
# 4
# Downloading prods_op_mogreps-uk_20140112_03_04_003.nc ...
# 5
# Downloading prods_op_mogreps-uk_20140112_03_05_003.nc ...
# 6
# Downloading prods_op_mogreps-uk_20140112_03_06_003.nc ...
# 7
# Downloading prods_op_mogreps-uk_20140112_03_07_003.nc ...
# 0
# Downloading prods_op_mogreps-uk_20140113_03_00_003.nc ...
# 1
# Downloading prods_op_mogreps-uk_20140113_03_01_003.nc ...
# 2
# Downloading prods_op_mogreps-uk_20140113_03_02_003.nc ...
# 3
# Downloading prods_op_mogreps-uk_20140113_03_03_003.nc ...
# 4
# Downloading prods_op_mogreps-uk_20140113_03_04_003.nc ...
# 5
# Downloading prods_op_mogreps-uk_20140113_03_05_003.nc ...
# 6
# Downloading prods_op_mogreps-uk_20140113_03_06_003.nc ...
# 7
# Downloading prods_op_mogreps-uk_20140113_03_07_003.nc ...
# 0
# Downloading prods_op_mogreps-uk_20140114_03_00_003.nc ...
# 1
# Downloading prods_op_mogreps-uk_20140114_03_01_003.nc ...
# 2
# Downloading prods_op_mogreps-uk_20140114_03_02_003.nc ...
# 3
# Downloading prods_op_mogreps-uk_20140114_03_03_003.nc ...
# 4
# Downloading prods_op_mogreps-uk_20140114_03_04_003.nc ...
# 5
# Downloading prods_op_mogreps-uk_20140114_03_05_003.nc ...
# 6
# Downloading prods_op_mogreps-uk_20140114_03_06_003.nc ...
# 7
# Downloading prods_op_mogreps-uk_20140114_03_07_003.nc ...
# 0
# Downloading prods_op_mogreps-uk_20140115_03_00_003.nc ...
# 1
# Downloading prods_op_mogreps-uk_20140115_03_01_003.nc ...
# 2
# Downloading prods_op_mogreps-uk_20140115_03_02_003.nc ...
# 3
# Downloading prods_op_mogreps-uk_20140115_03_03_003.nc ...
# 4
# Downloading prods_op_mogreps-uk_20140115_03_04_003.nc ...
# 5
# Downloading prods_op_mogreps-uk_20140115_03_05_003.nc ...
# 6
# Downloading prods_op_mogreps-uk_20140115_03_06_003.nc ...
# 7
# Downloading prods_op_mogreps-uk_20140115_03_07_003.nc ...
# 0
# Downloading prods_op_mogreps-uk_20140116_03_00_003.nc ...
# 1
# Downloading prods_op_mogreps-uk_20140116_03_01_003.nc ...
# 2
# Downloading prods_op_mogreps-uk_20140116_03_02_003.nc ...
# 3
# Downloading prods_op_mogreps-uk_20140116_03_03_003.nc ...
# 4
# Downloading prods_op_mogreps-uk_20140116_03_04_003.nc ...
# 5
# Downloading prods_op_mogreps-uk_20140116_03_05_003.nc ...
# 6
# Downloading prods_op_mogreps-uk_20140116_03_06_003.nc ...
# 7
# Downloading prods_op_mogreps-uk_20140116_03_07_003.nc ...
# 0
# Downloading prods_op_mogreps-uk_20140117_03_00_003.nc ...
# 1
# Downloading prods_op_mogreps-uk_20140117_03_01_003.nc ...
# 2
# Downloading prods_op_mogreps-uk_20140117_03_02_003.nc ...
# 3
# Downloading prods_op_mogreps-uk_20140117_03_03_003.nc ...
# 4
# Downloading prods_op_mogreps-uk_20140117_03_04_003.nc ...
# 5
# Downloading prods_op_mogreps-uk_20140117_03_05_003.nc ...
# 6
# Downloading prods_op_mogreps-uk_20140117_03_06_003.nc ...
# 7
# Downloading prods_op_mogreps-uk_20140117_03_07_003.nc ...
# 0
# Downloading prods_op_mogreps-uk_20140118_03_00_003.nc ...
# 1
# Downloading prods_op_mogreps-uk_20140118_03_01_003.nc ...
# 2
# Downloading prods_op_mogreps-uk_20140118_03_02_003.nc ...
# 3
# Downloading prods_op_mogreps-uk_20140118_03_03_003.nc ...
# 4
# Downloading prods_op_mogreps-uk_20140118_03_04_003.nc ...
# 5
# Downloading prods_op_mogreps-uk_20140118_03_05_003.nc ...
# 6
# Downloading prods_op_mogreps-uk_20140118_03_06_003.nc ...
# 7
# Downloading prods_op_mogreps-uk_20140118_03_07_003.nc ...
# 0
# Downloading prods_op_mogreps-uk_20140119_03_00_003.nc ...
# 1
# Downloading prods_op_mogreps-uk_20140119_03_01_003.nc ...
# 2
# Downloading prods_op_mogreps-uk_20140119_03_02_003.nc ...
# 3
# Downloading prods_op_mogreps-uk_20140119_03_03_003.nc ...
# 4
# Downloading prods_op_mogreps-uk_20140119_03_04_003.nc ...
# 5
# Downloading prods_op_mogreps-uk_20140119_03_05_003.nc ...
# 6
# Downloading prods_op_mogreps-uk_20140119_03_06_003.nc ...
# 7
# Downloading prods_op_mogreps-uk_20140119_03_07_003.nc ...
# 0
# Downloading prods_op_mogreps-uk_20140120_03_00_003.nc ...
# 1
# Downloading prods_op_mogreps-uk_20140120_03_01_003.nc ...
# 2
# Downloading prods_op_mogreps-uk_20140120_03_02_003.nc ...
# 3
# Downloading prods_op_mogreps-uk_20140120_03_03_003.nc ...
# 4
# Downloading prods_op_mogreps-uk_20140120_03_04_003.nc ...
# 5
# Downloading prods_op_mogreps-uk_20140120_03_05_003.nc ...
# 6
# Downloading prods_op_mogreps-uk_20140120_03_06_003.nc ...
# 7
# Downloading prods_op_mogreps-uk_20140120_03_07_003.nc ...
# 0
# Downloading prods_op_mogreps-uk_20140121_03_00_003.nc ...
# 1
# Downloading prods_op_mogreps-uk_20140121_03_01_003.nc ...
# 2
# Downloading prods_op_mogreps-uk_20140121_03_02_003.nc ...
# 3
# Downloading prods_op_mogreps-uk_20140121_03_03_003.nc ...
# 4
# Downloading prods_op_mogreps-uk_20140121_03_04_003.nc ...
# 5
# Downloading prods_op_mogreps-uk_20140121_03_05_003.nc ...
# 6
# Downloading prods_op_mogreps-uk_20140121_03_06_003.nc ...
# 7
# Downloading prods_op_mogreps-uk_20140121_03_07_003.nc ...
# 0
# Downloading prods_op_mogreps-uk_20140122_03_00_003.nc ...
# 1
# Downloading prods_op_mogreps-uk_20140122_03_01_003.nc ...
# 2
# Downloading prods_op_mogreps-uk_20140122_03_02_003.nc ...
# 3
# Downloading prods_op_mogreps-uk_20140122_03_03_003.nc ...
# 4
# Downloading prods_op_mogreps-uk_20140122_03_04_003.nc ...
# 5
# Downloading prods_op_mogreps-uk_20140122_03_05_003.nc ...
# 6
# Downloading prods_op_mogreps-uk_20140122_03_06_003.nc ...
# 7
# Downloading prods_op_mogreps-uk_20140122_03_07_003.nc ...
# 0
# Downloading prods_op_mogreps-uk_20140123_03_00_003.nc ...
# 1
# Downloading prods_op_mogreps-uk_20140123_03_01_003.nc ...
# 2
# Downloading prods_op_mogreps-uk_20140123_03_02_003.nc ...
# 3
# Downloading prods_op_mogreps-uk_20140123_03_03_003.nc ...
# 4
# Downloading prods_op_mogreps-uk_20140123_03_04_003.nc ...
# 5
# Downloading prods_op_mogreps-uk_20140123_03_05_003.nc ...
# 6
# Downloading prods_op_mogreps-uk_20140123_03_06_003.nc ...
# 7
# Downloading prods_op_mogreps-uk_20140123_03_07_003.nc ...
# 0
# Downloading prods_op_mogreps-uk_20140124_03_00_003.nc ...
# 1
# Downloading prods_op_mogreps-uk_20140124_03_01_003.nc ...
# 2
# Downloading prods_op_mogreps-uk_20140124_03_02_003.nc ...
# 3
# Downloading prods_op_mogreps-uk_20140124_03_03_003.nc ...
# 4
# Downloading prods_op_mogreps-uk_20140124_03_04_003.nc ...
# 5
# Downloading prods_op_mogreps-uk_20140124_03_05_003.nc ...
# 6
# Downloading prods_op_mogreps-uk_20140124_03_06_003.nc ...
# 7
# Downloading prods_op_mogreps-uk_20140124_03_07_003.nc ...
# 0
# Downloading prods_op_mogreps-uk_20140125_03_00_003.nc ...
# 1
# Downloading prods_op_mogreps-uk_20140125_03_01_003.nc ...
# 2
# Downloading prods_op_mogreps-uk_20140125_03_02_003.nc ...
# 3
# Downloading prods_op_mogreps-uk_20140125_03_03_003.nc ...
# 4
# Downloading prods_op_mogreps-uk_20140125_03_04_003.nc ...
# 5
# Downloading prods_op_mogreps-uk_20140125_03_05_003.nc ...
# 6
# Downloading prods_op_mogreps-uk_20140125_03_06_003.nc ...
# 7
# Downloading prods_op_mogreps-uk_20140125_03_07_003.nc ...
# 0
# Downloading prods_op_mogreps-uk_20140126_03_00_003.nc ...
# 1
# Downloading prods_op_mogreps-uk_20140126_03_01_003.nc ...
# 2
# Downloading prods_op_mogreps-uk_20140126_03_02_003.nc ...

# %%
# write means to file

def write_mean_netCDF(year,month,temp_mean, pres_mean, humidity_mean, wind_mean):
    
    template_string ="ensemble_means_{:02d}{:02d}.nc"
    
    file_name = template_string.format(
        year, month)
    
    dataset = nc.Dataset(file_name,'w')
    
    
    return
# Out:
# 82.28125
